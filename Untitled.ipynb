# %%
import base64
import json
import os
import ssl
try:
    import httplib  # Python 2
except:
    import http.client as httplib  # Python 3

headers = {"Content-type": "application/json",
           "X-Access-Token": "1pA3tbRowNsoFQTUW2r3RoRROOE7diux7E3S"}
conn = httplib.HTTPSConnection("dev.sighthoundapi.com", 
       context=ssl.SSLContext(ssl.PROTOCOL_TLSv1))

# To use a hosted image uncomment the following line and update the URL
# image_data = "https://en.wikipedia.org/wiki/Category:Images_of_cars#/media/File:Red_2007_gtcs_front.jpg"

# To use a local file uncomment the following line and update the path
image_data = base64.b64encode(open("/Users/sebastiennunes/Documents/BDCHackathon/asphalt-auto-automobile-170811.jpg", "rb").read()).decode()

params = json.dumps({"image": image_data})
conn.request("POST", "/v1/recognition?objectType=vehicle", params, headers
            )
response = conn.getresponse()
result = response.read()
json_out = result.decode("utf-8")
    
print(json_out)
# Out:
# {"image":{"width":4912,"height":2760,"orientation":1},"requestId":"75787cbf24d24aa59f827772241366ed","objects":[{"objectId":"_vehicle_f3c3d26b-c568-4d98-b6db-b96659fd7766","vehicleAnnotation":{"bounding":{"vertices":[{"x":341,"y":254},{"x":4639,"y":254},{"x":4639,"y":2486},{"x":341,"y":2486}]},"recognitionConfidence":0.6224,"attributes":{"system":{"make":{"name":"BMW","confidence":0.8381},"model":{"name":"3 Series","confidence":0.6224},"color":{"name":"blue","confidence":0.9996},"vehicleType":"car"}}},"objectType":"vehicle"}]}

# %%
try:
        obj = json.loads(json_out)
        
        #get make
        make = obj["objects"][0]["vehicleAnnotation"]["attributes"]["system"]["make"]["name"]
        
        #get model 
        model = obj["objects"][0]["vehicleAnnotation"]["attributes"]["system"]["model"]["name"]
        
        #get color
        color = obj["objects"][0]["vehicleAnnotation"]["attributes"]["system"]["color"]["name"]
        
        #print(obj)
        print(make)
        print(model)
        print(color)
except ValueError:
    print ("error loading JSON")
# Out:
# BMW
# 3 Series
# blue

# %%
import pymysql.cursors
import pymysql

city_name = "Goldsboro"
connection = pymysql.connect(host='hackathon-db.bdc.n360.io',
                             user='events',
                             password='Hack@th0n2019',
                             db='db',
                             charset='utf8mb4',
                             database='hackathon',
                             cursorclass=pymysql.cursors.DictCursor)

try:
    with connection.cursor() as cursor:
        # Create a new record
        sql = """ SELECT car_inventory.inventory_id, car_id, inventory_make, inventory_model, price, car_year, fuel, car_status, organization_name, address, phone, car_int_photo_url1
							FROM
							(
								(SELECT inventory_id, dealers.organization_unit_id, organization_name, address, phone
								FROM
									(SELECT * 
									FROM organization_unit
									WHERE city = %s) dealers
									INNER JOIN
									(SELECT *
									FROM organization_unit_inventory ) inventories
									ON dealers.organization_unit_id = inventories.organization_unit_id
									) local_dealers
							    INNER JOIN
									(SELECT * 
									FROM car_inventory) car_inventory
							    ON car_inventory.inventory_id = local_dealers.inventory_id
							)
							WHERE car_status = 'FOR_SALE' ;
							"""
        
        cursor.execute(sql, (city_name))
        result = cursor.fetchall()
        print(result)

    # connection is not autocommit by default. So you must commit to save
    # your changes.
    connection.commit()

finally:
    connection.close()
# Out:
# [{'inventory_id': 737, 'car_id': 5066914, 'inventory_make': 'Subaru', 'inventory_model': 'Forester', 'price': Decimal('35303.00'), 'car_year': 2017, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/2017/subaru/forester/2-5i-touring/suv/interiorColors/2017_subaru_forester_2-5i-tourisme_vus_tissu-gris-platine_avant.jpg'}, {'inventory_id': 737, 'car_id': 5215609, 'inventory_make': 'Subaru', 'inventory_model': 'Forester', 'price': Decimal('41280.00'), 'car_year': 2018, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/2018/subaru/forester/2-0xt-limited/suv/interiorColors/2018_subaru_forester_2-0xt-limited_vus_cuir-brun_avant.jpg'}, {'inventory_id': 737, 'car_id': 5589462, 'inventory_make': 'Subaru', 'inventory_model': 'ASCENT', 'price': Decimal('42855.00'), 'car_year': 2019, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/2019/subaru/ascent/touring/suv/interiorColors/2019_subaru_ascent_tourisme_tissu_premium_noir_avant.jpg'}, {'inventory_id': 737, 'car_id': 5597803, 'inventory_make': 'Subaru', 'inventory_model': 'WRX', 'price': Decimal('0.00'), 'car_year': 2019, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/ca/2019/subaru/wrx/sport/sedan/interiorColors/2019_subaru_wrx_sport_tissu-noir-onyx_avant.jpg'}, {'inventory_id': 737, 'car_id': 5609646, 'inventory_make': 'Subaru', 'inventory_model': 'WRX', 'price': Decimal('35105.00'), 'car_year': 2019, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/ca/2019/subaru/wrx/sport/sedan/interiorColors/2019_subaru_wrx_sport_tissu-noir-onyx_avant.jpg'}, {'inventory_id': 737, 'car_id': 5623644, 'inventory_make': 'Subaru', 'inventory_model': 'ASCENT', 'price': Decimal('43355.00'), 'car_year': 2019, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/2019/subaru/ascent/touring/suv/interiorColors/2019_subaru_ascent_tourisme_tissu_premium_noir_avant.jpg'}, {'inventory_id': 737, 'car_id': 5634703, 'inventory_make': 'Subaru', 'inventory_model': 'WRX STI', 'price': Decimal('49340.00'), 'car_year': 2019, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/ca/2019/subaru/wrx-sti/sti-sport-tech-with-wing-spoiler/sedan/interiorColors/2019_subaru_wrx-sti_sport-tech_berline_cuir-noir-anthracite-avec-insertions-rouges_avant.jpg'}, {'inventory_id': 737, 'car_id': 5657496, 'inventory_make': 'Subaru', 'inventory_model': 'WRX STI', 'price': Decimal('49340.00'), 'car_year': 2019, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name': 'America Online', 'address': '805 Chamberlain Way', 'phone': '(559) 587-0766', 'car_int_photo_url1': 'https://img.sm360.ca/images/newcar/ca/2019/subaru/wrx-sti/sti-sport-tech-with-lip-spoiler/sedan/interiorColors/2019_subaru_wrx-sti_sport-tech_berline_cuir-noir-anthracite-avec-insertions-rouges_avant.jpg'}, {'inventory_id': 737, 'car_id': 5662915, 'inventory_make': 'Subaru', 'inventory_model': 'Impreza', 'price': Decimal('33200.00'), 'car_year': 2019, 'fuel': 'Gasoline', 'car_status': 'FOR_SALE', 'organization_name' ...
